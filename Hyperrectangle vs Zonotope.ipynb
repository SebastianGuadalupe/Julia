# %%
using LazySets, NeuralVerification, Plots

# %%
function Box(X, W, b)
    Y = overapproximate(W * X + b, Hyperrectangle)
    return rectify(Y)
end
# Out:
# Box (generic function with 1 method)

# %%
X = rand(Zonotope)
W = rand(2, 2)
b = rand(2)
# Out:
# 2-element Array{Float64,1}:
#  0.8243888149368837
#  0.8386230931134107

# %%
plot(affine_map(W, X, b), label="original")
plot!(Box(X, W, b), label="Box()")
plot!(overapproximate(Rectification(affine_map(W, X, b)), Zonotope), label="overapproximate")
